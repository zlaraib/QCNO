# %%
from qiskit import QuantumCircuit
from qiskit_ibm_provider import IBMProvider
from qiskit import Aer, transpile

# Save account credentials.
# IBMProvider.save_account(token=MY_API_TOKEN)

# Load previously saved account credentials.
# provider = IBMProvider()

# Construct a noisy simulator backend from an IBMQ backend
# This simulator backend will be automatically configured
# using the device configuration and noise model 

# provider = IBMProvider()
# provider = IBMProvider(instance="ibm-q-ornl/ornl/csc500")

# Select a backend.
backend = Aer.get_backend('aer_simulator')
# backend = provider.get_backend('simulator_mps')
#backend = provider.get_backend('ibmq_qasm_simulator')
#Display current supported backends
# print(provider.backends())

# %%
# %matplotlib inline
# Importing standard Qiskit libraries
from qiskit import *
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
#
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from scipy import linalg as la
from qiskit_textbook.tools import array_to_latex
from math import pi

# %% [markdown]
# We will perform the transeverse field Ising model (TFIM) by using Trotter expansion
#
# The many-body spin (nearest-neighbour) Hamiltnonian is given by:
#
# <!-- $$ \mathcal{H}= -J \sum_{i}\sigma^z_i\sigma^z_{i+1} - B \sum_i \sigma^x_i $$ -->
# $$ \mathcal{H}= J_{ij} \sum_{i}\vec{\sigma_i} \cdot \vec{\sigma_{i+1}} $$
# This is an exactly solvable model. So, we will simulate time eveolution of two-spin wave function:
#
# $$ | \Psi (t + \Delta t) > = e^{-i \mathcal{H} t} | \Psi(t)> $$
#
# where the Trotterized Hamiltonian operator is
#
# $$ e^{-i \mathcal{H} t} =  CX(q_0,q_1) ~ R_{1}^{z} (-2 \Delta t J_{ij}) ~ CX(q_0,q_1) ~ R_{1}^{y} (-2 \Delta t J_{ij}) ~ CX(q_0,q_1) ~ R_{1}^{x} (-2 \Delta t J_{ij}) + O(\Delta t^2)$$

# %%
### Physical parameters (atomic units) ###
#dt = 0.01  # Time-discretization unit
J_ij= 1/4 # (1/2*n_sites) for 2 qubits

# %%
### Build a circuit ###

#circ = QuantumCircuit(2, 2)  # 2 quantum & 2 classical registers
def self_int(circ,q0,q1,c0,c1,dt):
    circ.x(0)
     
    circ.rz(2*dt*J_ij, 1)
    circ.cx(0, 1)


    circ.ry(2*dt*J_ij, 1)
    circ.cx(0, 1) 


    circ.rx(2*dt*J_ij, 1)
    circ.cx(0, 1) 
 
    # circ.rx(2*dt*J_ij, 0)  # Transverse-field propagation of spin 0
    # circ.rx(2*dt*J_ij, 1)
    # circ.cx(0, 1) 
    # circ.ry(2*dt*J_ij, 0)  # Transverse-field propagation of spin 0
    # circ.ry(2*dt*J_ij, 1)
    # circ.cx(0, 1) 
    # circ.rz(2*dt*J_ij, 0)  # Transverse-field propagation of spin 0
    # circ.rz(2*dt*J_ij, 1)
    # circ.cx(0, 1) 
    
    circ.measure(range(2), range(2))  # Measure both spins

# %%
# Draw full circuit

q = QuantumRegister(2, "q")
c = ClassicalRegister(2, "c")
# Define Ising Model Circuit "ic" for simulation
ic = QuantumCircuit(q,c)

dt=0.05

self_int(ic,0,1,0,1,dt)

ic.draw('mpl')
# Out:
# /home/zohalaraib/.local/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
# Transpile the quantum circuit to low-level QASM instructions
#from qiskit import transpile
#circ_compiled = transpile(circ, backend)

# %%
# Execute the circuit on the Qasm simulator, repeating 1024 times
#job_sim = backend.run(circ_compiled, shots=1024)

# %%
# Grab the results from the job
#result_sim = job_sim.result()

# %%
def digit_sum(n):
    num_str = str(n)
    sum = 0
    for i in range(0, len(num_str)):
        sum += int(num_str[i])
    return sum

# %%
# SIMULATOR #

shots = 1024
coupling_map = None
mag_sim = []

for i in range(200):
    q = QuantumRegister(2, "q")
    c = ClassicalRegister(2, "c")
    # Define Ising Model Circuit "ic" for simulation
    ic = QuantumCircuit(q,c)
    
    # dt=i*0.013
    dt = i* 0.05
    self_int(ic,q[0],q[1],c[0],c[1],dt)
    
    result = execute(ic, backend=backend,
                    coupling_map=coupling_map, shots=shots).result()
    res = result.get_counts(ic)
    
    #print("res = ", res)
    
    r1=list(res.keys())
    
    #print("r1 - keys = ", r1, "len(r1) = ", len(r1))
    
    r2=list(res.values())
    
    #print("r2 - values = ", r2)
    
    print("                          ")
    
#===============================    
    M=0
    
    for j in range(0,len(r1)):
        
        print("digit_sum(r1[j] = ", digit_sum(r1[j]))
        print("r2[j] = ", r2[j])
        print("                  ")
        
        M = M + (2 - 1*digit_sum(r1[j]))*r2[j]/shots
        
    # print("time: ",dt, ";  <sigma_z>: ", M/2)
    print("                  ")
    
    mag_sim.append(M/2)
# Out:
#
# digit_sum(r1[j] =  2
# r2[j] =  1024
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  1024
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  1
#
# digit_sum(r1[j] =  2
# r2[j] =  1023
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  5
#
# digit_sum(r1[j] =  2
# r2[j] =  1019
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  4
#
# digit_sum(r1[j] =  2
# r2[j] =  1020
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  15
#
# digit_sum(r1[j] =  2
# r2[j] =  1009
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  12
#
# digit_sum(r1[j] =  2
# r2[j] =  1012
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  22
#
# digit_sum(r1[j] =  2
# r2[j] =  1002
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  26
#
# digit_sum(r1[j] =  2
# r2[j] =  998
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  32
#
# digit_sum(r1[j] =  2
# r2[j] =  992
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  19
#
# digit_sum(r1[j] =  2
# r2[j] =  1005
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  42
#
# digit_sum(r1[j] =  2
# r2[j] =  982
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  47
#
# digit_sum(r1[j] =  2
# r2[j] =  977
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  57
#
# digit_sum(r1[j] =  2
# r2[j] =  967
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  50
#
# digit_sum(r1[j] =  2
# r2[j] =  974
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  53
#
# digit_sum(r1[j] =  2
# r2[j] =  971
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  59
#
# digit_sum(r1[j] =  2
# r2[j] =  965
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  75
#
# digit_sum(r1[j] =  2
# r2[j] =  949
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  97
#
# digit_sum(r1[j] =  2
# r2[j] =  927
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  102
#
# digit_sum(r1[j] =  2
# r2[j] =  922
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  112
#
# digit_sum(r1[j] =  2
# r2[j] =  912
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  125
#
# digit_sum(r1[j] =  2
# r2[j] =  899
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  862
#
# digit_sum(r1[j] =  1
# r2[j] =  162
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  161
#
# digit_sum(r1[j] =  2
# r2[j] =  863
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  161
#
# digit_sum(r1[j] =  2
# r2[j] =  863
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  155
#
# digit_sum(r1[j] =  2
# r2[j] =  869
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  845
#
# digit_sum(r1[j] =  1
# r2[j] =  179
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  206
#
# digit_sum(r1[j] =  2
# r2[j] =  818
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  214
#
# digit_sum(r1[j] =  2
# r2[j] =  810
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  794
#
# digit_sum(r1[j] =  1
# r2[j] =  230
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  214
#
# digit_sum(r1[j] =  2
# r2[j] =  810
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  746
#
# digit_sum(r1[j] =  1
# r2[j] =  278
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  765
#
# digit_sum(r1[j] =  1
# r2[j] =  259
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  284
#
# digit_sum(r1[j] =  2
# r2[j] =  740
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  730
#
# digit_sum(r1[j] =  1
# r2[j] =  294
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  290
#
# digit_sum(r1[j] =  2
# r2[j] =  734
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  722
#
# digit_sum(r1[j] =  1
# r2[j] =  302
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  694
#
# digit_sum(r1[j] =  1
# r2[j] =  330
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  345
#
# digit_sum(r1[j] =  2
# r2[j] =  679
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  672
#
# digit_sum(r1[j] =  1
# r2[j] =  352
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  634
#
# digit_sum(r1[j] =  1
# r2[j] =  390
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  640
#
# digit_sum(r1[j] =  1
# r2[j] =  384
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  605
#
# digit_sum(r1[j] =  1
# r2[j] =  419
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  398
#
# digit_sum(r1[j] =  2
# r2[j] =  626
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  404
#
# digit_sum(r1[j] =  2
# r2[j] =  620
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  608
#
# digit_sum(r1[j] =  1
# r2[j] =  416
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  557
#
# digit_sum(r1[j] =  1
# r2[j] =  467
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  423
#
# digit_sum(r1[j] =  2
# r2[j] =  601
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  596
#
# digit_sum(r1[j] =  1
# r2[j] =  428
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  460
#
# digit_sum(r1[j] =  2
# r2[j] =  564
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  447
#
# digit_sum(r1[j] =  2
# r2[j] =  577
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  473
#
# digit_sum(r1[j] =  2
# r2[j] =  551
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  483
#
# digit_sum(r1[j] =  2
# r2[j] =  541
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  578
#
# digit_sum(r1[j] =  1
# r2[j] =  446
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  468
#
# digit_sum(r1[j] =  2
# r2[j] =  556
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  483
#
# digit_sum(r1[j] =  2
# r2[j] =  541
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  512
#
# digit_sum(r1[j] =  2
# r2[j] =  512
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  516
#
# digit_sum(r1[j] =  1
# r2[j] =  508
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  512
#
# digit_sum(r1[j] =  2
# r2[j] =  512
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  527
#
# digit_sum(r1[j] =  2
# r2[j] =  497
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  522
#
# digit_sum(r1[j] =  2
# r2[j] =  502
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  494
#
# digit_sum(r1[j] =  1
# r2[j] =  530
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  549
#
# digit_sum(r1[j] =  1
# r2[j] =  475
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  506
#
# digit_sum(r1[j] =  2
# r2[j] =  518
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  518
#
# digit_sum(r1[j] =  2
# r2[j] =  506
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  536
#
# digit_sum(r1[j] =  2
# r2[j] =  488
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  536
#
# digit_sum(r1[j] =  2
# r2[j] =  488
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  492
#
# digit_sum(r1[j] =  2
# r2[j] =  532
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  504
#
# digit_sum(r1[j] =  2
# r2[j] =  520
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  506
#
# digit_sum(r1[j] =  1
# r2[j] =  518
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  470
#
# digit_sum(r1[j] =  2
# r2[j] =  554
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  539
#
# digit_sum(r1[j] =  1
# r2[j] =  485
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  502
#
# digit_sum(r1[j] =  2
# r2[j] =  522
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  480
#
# digit_sum(r1[j] =  2
# r2[j] =  544
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  479
#
# digit_sum(r1[j] =  2
# r2[j] =  545
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  556
#
# digit_sum(r1[j] =  1
# r2[j] =  468
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  551
#
# digit_sum(r1[j] =  1
# r2[j] =  473
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  450
#
# digit_sum(r1[j] =  2
# r2[j] =  574
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  417
#
# digit_sum(r1[j] =  2
# r2[j] =  607
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  442
#
# digit_sum(r1[j] =  2
# r2[j] =  582
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  405
#
# digit_sum(r1[j] =  2
# r2[j] =  619
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  447
#
# digit_sum(r1[j] =  2
# r2[j] =  577
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  375
#
# digit_sum(r1[j] =  2
# r2[j] =  649
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  381
#
# digit_sum(r1[j] =  2
# r2[j] =  643
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  428
#
# digit_sum(r1[j] =  2
# r2[j] =  596
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  655
#
# digit_sum(r1[j] =  1
# r2[j] =  369
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  369
#
# digit_sum(r1[j] =  2
# r2[j] =  655
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  376
#
# digit_sum(r1[j] =  2
# r2[j] =  648
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  671
#
# digit_sum(r1[j] =  1
# r2[j] =  353
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  331
#
# digit_sum(r1[j] =  2
# r2[j] =  693
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  318
#
# digit_sum(r1[j] =  2
# r2[j] =  706
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  707
#
# digit_sum(r1[j] =  1
# r2[j] =  317
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  736
#
# digit_sum(r1[j] =  1
# r2[j] =  288
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  290
#
# digit_sum(r1[j] =  2
# r2[j] =  734
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  252
#
# digit_sum(r1[j] =  2
# r2[j] =  772
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  234
#
# digit_sum(r1[j] =  2
# r2[j] =  790
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  242
#
# digit_sum(r1[j] =  2
# r2[j] =  782
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  227
#
# digit_sum(r1[j] =  2
# r2[j] =  797
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  217
#
# digit_sum(r1[j] =  2
# r2[j] =  807
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  830
#
# digit_sum(r1[j] =  1
# r2[j] =  194
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  860
#
# digit_sum(r1[j] =  1
# r2[j] =  164
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  163
#
# digit_sum(r1[j] =  2
# r2[j] =  861
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  151
#
# digit_sum(r1[j] =  2
# r2[j] =  873
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  148
#
# digit_sum(r1[j] =  2
# r2[j] =  876
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  134
#
# digit_sum(r1[j] =  2
# r2[j] =  890
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  119
#
# digit_sum(r1[j] =  2
# r2[j] =  905
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  122
#
# digit_sum(r1[j] =  2
# r2[j] =  902
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  109
#
# digit_sum(r1[j] =  2
# r2[j] =  915
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  99
#
# digit_sum(r1[j] =  2
# r2[j] =  925
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  84
#
# digit_sum(r1[j] =  2
# r2[j] =  940
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  85
#
# digit_sum(r1[j] =  2
# r2[j] =  939
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  79
#
# digit_sum(r1[j] =  2
# r2[j] =  945
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  41
#
# digit_sum(r1[j] =  2
# r2[j] =  983
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  36
#
# digit_sum(r1[j] =  2
# r2[j] =  988
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  39
#
# digit_sum(r1[j] =  2
# r2[j] =  985
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  39
#
# digit_sum(r1[j] =  2
# r2[j] =  985
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  36
#
# digit_sum(r1[j] =  2
# r2[j] =  988
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  26
#
# digit_sum(r1[j] =  2
# r2[j] =  998
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  12
#
# digit_sum(r1[j] =  2
# r2[j] =  1012
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  22
#
# digit_sum(r1[j] =  2
# r2[j] =  1002
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  12
#
# digit_sum(r1[j] =  2
# r2[j] =  1012
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  5
#
# digit_sum(r1[j] =  2
# r2[j] =  1019
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  6
#
# digit_sum(r1[j] =  2
# r2[j] =  1018
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  4
#
# digit_sum(r1[j] =  2
# r2[j] =  1020
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  2
#
# digit_sum(r1[j] =  2
# r2[j] =  1022
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  1024
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  1024
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  1024
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  3
#
# digit_sum(r1[j] =  2
# r2[j] =  1021
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  3
#
# digit_sum(r1[j] =  2
# r2[j] =  1021
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  9
#
# digit_sum(r1[j] =  2
# r2[j] =  1015
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  9
#
# digit_sum(r1[j] =  2
# r2[j] =  1015
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  15
#
# digit_sum(r1[j] =  2
# r2[j] =  1009
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  17
#
# digit_sum(r1[j] =  2
# r2[j] =  1007
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  23
#
# digit_sum(r1[j] =  2
# r2[j] =  1001
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  996
#
# digit_sum(r1[j] =  1
# r2[j] =  28
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  42
#
# digit_sum(r1[j] =  2
# r2[j] =  982
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  40
#
# digit_sum(r1[j] =  2
# r2[j] =  984
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  50
#
# digit_sum(r1[j] =  2
# r2[j] =  974
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  69
#
# digit_sum(r1[j] =  2
# r2[j] =  955
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  963
#
# digit_sum(r1[j] =  1
# r2[j] =  61
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  67
#
# digit_sum(r1[j] =  2
# r2[j] =  957
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  91
#
# digit_sum(r1[j] =  2
# r2[j] =  933
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  84
#
# digit_sum(r1[j] =  2
# r2[j] =  940
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  86
#
# digit_sum(r1[j] =  2
# r2[j] =  938
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  109
#
# digit_sum(r1[j] =  2
# r2[j] =  915
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  126
#
# digit_sum(r1[j] =  2
# r2[j] =  898
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  145
#
# digit_sum(r1[j] =  2
# r2[j] =  879
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  859
#
# digit_sum(r1[j] =  1
# r2[j] =  165
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  171
#
# digit_sum(r1[j] =  2
# r2[j] =  853
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  845
#
# digit_sum(r1[j] =  1
# r2[j] =  179
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  163
#
# digit_sum(r1[j] =  2
# r2[j] =  861
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  175
#
# digit_sum(r1[j] =  2
# r2[j] =  849
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  188
#
# digit_sum(r1[j] =  2
# r2[j] =  836
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  813
#
# digit_sum(r1[j] =  1
# r2[j] =  211
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  255
#
# digit_sum(r1[j] =  2
# r2[j] =  769
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  234
#
# digit_sum(r1[j] =  2
# r2[j] =  790
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  261
#
# digit_sum(r1[j] =  2
# r2[j] =  763
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  290
#
# digit_sum(r1[j] =  2
# r2[j] =  734
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  747
#
# digit_sum(r1[j] =  1
# r2[j] =  277
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  289
#
# digit_sum(r1[j] =  2
# r2[j] =  735
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  725
#
# digit_sum(r1[j] =  1
# r2[j] =  299
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  707
#
# digit_sum(r1[j] =  1
# r2[j] =  317
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  673
#
# digit_sum(r1[j] =  1
# r2[j] =  351
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  701
#
# digit_sum(r1[j] =  1
# r2[j] =  323
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  676
#
# digit_sum(r1[j] =  1
# r2[j] =  348
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  360
#
# digit_sum(r1[j] =  2
# r2[j] =  664
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  637
#
# digit_sum(r1[j] =  1
# r2[j] =  387
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  390
#
# digit_sum(r1[j] =  2
# r2[j] =  634
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  404
#
# digit_sum(r1[j] =  2
# r2[j] =  620
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  593
#
# digit_sum(r1[j] =  1
# r2[j] =  431
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  433
#
# digit_sum(r1[j] =  2
# r2[j] =  591
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  598
#
# digit_sum(r1[j] =  1
# r2[j] =  426
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  600
#
# digit_sum(r1[j] =  1
# r2[j] =  424
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  569
#
# digit_sum(r1[j] =  1
# r2[j] =  455
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  586
#
# digit_sum(r1[j] =  1
# r2[j] =  438
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  584
#
# digit_sum(r1[j] =  1
# r2[j] =  440
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  478
#
# digit_sum(r1[j] =  2
# r2[j] =  546
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  530
#
# digit_sum(r1[j] =  1
# r2[j] =  494
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  525
#
# digit_sum(r1[j] =  1
# r2[j] =  499
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  520
#
# digit_sum(r1[j] =  2
# r2[j] =  504
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  470
#
# digit_sum(r1[j] =  2
# r2[j] =  554
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  516
#
# digit_sum(r1[j] =  2
# r2[j] =  508
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  497
#
# digit_sum(r1[j] =  2
# r2[j] =  527
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  511
#
# digit_sum(r1[j] =  2
# r2[j] =  513
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  516
#
# digit_sum(r1[j] =  1
# r2[j] =  508
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  466
#
# digit_sum(r1[j] =  2
# r2[j] =  558
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  508
#
# digit_sum(r1[j] =  2
# r2[j] =  516
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  531
#
# digit_sum(r1[j] =  2
# r2[j] =  493
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  503
#
# digit_sum(r1[j] =  1
# r2[j] =  521
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  520
#
# digit_sum(r1[j] =  2
# r2[j] =  504
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  502
#
# digit_sum(r1[j] =  2
# r2[j] =  522
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  522
#
# digit_sum(r1[j] =  1
# r2[j] =  502
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  502
#
# digit_sum(r1[j] =  2
# r2[j] =  522
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  495
#
# digit_sum(r1[j] =  2
# r2[j] =  529
#
#
#
# digit_sum(r1[j] =  2
# r2[j] =  523
#
# digit_sum(r1[j] =  1
# r2[j] =  501
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  496
#
# digit_sum(r1[j] =  2
# r2[j] =  528
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  482
#
# digit_sum(r1[j] =  2
# r2[j] =  542
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  495
#
# digit_sum(r1[j] =  2
# r2[j] =  529
#
#
#
# digit_sum(r1[j] =  1
# r2[j] =  494
#
# digit_sum(r1[j] =  2
# r2[j] =  530

# %%
# Plot histogram
#from qiskit.visualization import plot_histogram
#plot_histogram(counts)

# %%
result = execute(ic, backend).result()
counts = result.get_counts(ic)
plot_histogram(counts, title="Self-interaction Circuit")

# %%
# Plot results

l1=np.arange(0.0,10.0,0.05)
#l1=np.arange(0.0,20.0,0.05)
plt.figure(figsize=(9,5))
#plt.plot(l,vexact(l),'k',label='exact')
plt.plot(l1, mag_sim, 'bo',label='aer_simulator')
#plt.plot(l1, mag_sim, 'bo',label='simulator_mps')
#plt.plot(l1, mag_sim, 'r*',label='ibmq_qasm_simulator')
#plt.xlabel('$\lambda$')
plt.xlabel('time')
plt.ylabel('$<\sigma_{z}>$')
plt.legend()
plt.title('Evolution of $\\sigma_z$ over Time')
plt.show()
